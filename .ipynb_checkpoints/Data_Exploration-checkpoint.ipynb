# %%
import pandas as pd
import numpy as np
import random
import pause

# %%
pd.set_option('display.max_colwidth', -1)

# %%
def clean_info(df):
    pd.set_option('display.max_colwidth', -1) 
    df['Year'] = df['Info'].str[8:12]
    df = df[df['Year'].str.contains("19")]
    df['Year'] = df['Year'].astype(int)
    df = df[(df['Year'] >= 1926) & (df['Year'] < 1960)]
    
    df['Artist Info'] = df['Info'].str[13:]
    df['MP3 Avaliable'] = 'Online'
    # Find multi-links:
    df['comma_loc'] = df['Download_link'].str.find(",")
    df['Link'] = np.where(df['comma_loc'] == -1, df['Download_link'], df['Download_link'].str[:47])
    df['Artist'] = df['Artist'].str.strip()
    
    return df[['Artist', 'Title', 'Year', 'MP3 Avaliable', 'Link']]

# %%
data = pd.read_csv('jazz_on_line/jazz_on_line/data/results_000056.csv')
output = clean_info(data)
#filename = str(input("filename"))
print len(output)
output[:60]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-df61a4666d5c> in <module>()
# ----> 1 data = pd.read_csv('jazz_on_line/jazz_on_line/data/results_000056.csv')
#       2 output = clean_info(data)
#       3 #filename = str(input("filename"))
#       4 print len(output)
#       5 output[:60]
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# IOError: File jazz_on_line/jazz_on_line/data/results_000056.csv does not exist

# %%
output.to_csv('jazz_on_line/Data' + filename + '.csv')

# %% [markdown]
# ## Download MP3s from Jazz-on-Line

# %%
df_download = pd.read_csv('music_downloads/DownloadA.csv')

df_download.shape
# Out:
# (1820, 7)

# %%
##Load & Clean Download CSV

csv_file = 'music_downloads/DownloadA.csv'

def clean_download_list(csv_file):
    
    #Load the file
    df_download = pd.read_csv(csv_file)

    #Create unique filenames for mp3 (ID & Style)
    df_download['Style-Katie'] = df_download['Style-Katie'].replace("Lindy Hop", "Lindy")
    df_download['filename'] = (df_download['ID'].astype(str)
                                            .str.zfill(4)
                                            + '-' +
                                            df_download['Style-Katie'])
    #Drop duplicate filepaths (keep last)
    df_download.drop_duplicates(subset='Link', keep='last', inplace=True)
    
    return df_download

# %%
df_download = clean_download_list('music_downloads/DownloadA.csv')

df_download[100:140]
# Out:
#        ID                                        Artist  \
# 103  627   Ozzie Nelson And His Orchestra
# 104  973   New Orleans Rhythm Kings, George Brunies, tb
# 105  784   Willie Lewis And His Negro Band
# 106  1800  Tommy Dorsey And His Orchestra
# 107  1672  Miles Davis All Stars
# 108  544   Bill Osborne's Heptette
# 110  1257  Noble Sissle And His Orchestra
# 111  210   Halfway House Orchestra
# 112  1515  Maxine Sullivan
# 113  1558  Count Basie And His Orchestra
# 114  203   Jimmie Lunceford And His Orchestra
# 115  381   Sarah Vaughan
# 116  1329  Bing Crosby
# 117  89    Meade Lux Lewis
# 118  14    Andy Kirk And His Twelve Clouds Of Joy
# 120  1239  Slim And Slam
# 121  74    Joe Venuti's Blue Four
# 122  1559  Una Mae Carlisle
# 123  668   Tony Bennett
# 124  62    Clarence Williams And His Orchestra
# 125  1550  Art Tatum
# 126  599   Jerry Colonna
# 127  176   Ruth Etting
# 128  1349  The Troubadors
# 129  497   Jo Stafford
# 130  127   Bob Haring And His Orchestra
# 131  517   Doris Day Feat. John Rarig's Orchestra
# 132  1782  Eddie Lockjaw Davis
# 133  1606  Ed Green - Billy Higgins And Company
                    output.write(mp3file.read())
                #Pause between 3rd of a second to 3 and a half seconds
                pause.milliseconds(random.randint(300, 3500)) 
            except:
                print "{} is not valid :  {}".format(mp3, name) 
                with open('error.txt', 'a') as f:
                    f.write('{},{},{}\n'.format(name[:4],mp3,name))

# %%
start = 140
stop = 185

download_mp3(df_download, start, stop)
# Out:
# http://www.jazz-on-line.com/a/2017/BB502976.mp3 is not valid :  0123-Lindy
# http://www.jazz-on-line.com/a/mp3c/VIC40314-2.mp3 is not valid :  0136-None

# %%
def download_mp3(df, start, stop):

    #Check batch size
    if stop-start > 50:
        print "batch is too large"
    else:
        count = 0
        for mp3, name in zip(df['Link'][start:stop], df['filename'][start:stop]):
            try:
                #Set User-Agent
                req = urllib2.Request(mp3, headers={ 'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36' })
                #open mp3 URL for song, download & save
                mp3file = urllib2.urlopen(req)
                with open('music_downloads/{}.mp3'.format(name),'wb') as output:
                    output.write(mp3file.read())

                #Add to count
                count += 1

                #Pause between 0.3 of a second to 3.5 seconds before next song
                pause.milliseconds(random.randint(300, 3500))

            except:
                #If URL/mp3 reading fails record ID, URL and filename in csv log
                print "{} is not valid :  {}".format(mp3, name)
                with open('error.txt', 'a') as f:
                    f.write('{},{},{}\n'.format(name[:4],mp3,name))

        print "{} mp3 files downloaded to 'music_downloads'".format(count)

# %%
download_mp3_test(df_download, 250, 254)
# Out:
# 4 mp3 files downloaded to 'music_downloads'

# %%
start = 205
stop = 207

download_mp3_test(df_2, start, stop)
# Out:
# 2 mp3 files downloaded to 'music_downloads'

# %% [markdown]
# Assigned to this machine (up to row 900)
#
# Assigned to Matt's mini mac (from 900 to 1300)

# %%
import youtube_dl

options = {'format': 'bestaudio/best',
           'extractaudio' : True,  # only keep the audio
           'audioformat' : "mp3",  # convert to mp3 
           'outtmpl': '%(id)s',    # name the file the ID of the video
           'noplaylist' : True,    # Download single song only
          }

with youtube_dl.YoutubeDL(options) as ytdl:
    youtube_mp3 = ytdl.download(['https://www.youtube.com/watch?v=wt1GzAMA6yY'])
    name = 'wt1GzAMA6yY'
    with open('music_downloads/{}.mp3'.format(name),'wb') as output:
        output.write(youtube_mp3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-151-b209cfc3a446> in <module>()
# ----> 1 import youtube_dl
#       2
#       3 options = {'format': 'bestaudio/best',
#       4            'extractaudio' : True,  # only keep the audio
#       5            'audioformat' : "mp3",  # convert to mp3
#
# ImportError: No module named youtube_dl

# %%
df = pd.read_csv('metadata_downloads/Swing_Dance_Style_Master_DownloadA.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c9604bb5e36b> in <module>()
# ----> 1 df = pd.read_csv('metadata_downloads/Swing_Dance_Style_Master_DownloadA.csv', index='ID')
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
df.set_index('ID')
# Out:
#                                                                      Artist  \
# ID
#  296.0   Aaftac Symphonette
#  1795.0  Abe Lyman And His California Orchestra
#  416.0   Abe Lyman's California Orchestra
#  1536.0  Abe Lyman's California Orchestra
#  1647.0  Adelaide Hall
#  116.0   Adrian Rollini And His Orchestra
#  574.0   Adrian Rollini And His Tap Room Gang
#  972.0   Ahmad Jamal
#  1362.0  Ahmad Jamal
#  868.0   Ahmad Jamal Trio
#  1811.0  Ahmad Jamal Trio
#  542.0   Aimé Barelli
#  451.0   Picnic In Purgatory                                          1942.0
#  855.0   Bumble Boogie                                                1946.0
#  1183.0  Deep In The Heart Of Texas                                   1941.0
#  1700.0  Deep In The Heart Of Texas                                   1941.0
#  725.0   Lullaby Of Broadway (V Sam Browne & The Rhythm Brothers)     1935.0
# ...                             ...                                      ...
#  389.0   Shoe Shine Boy                                               1936.0
#  786.0   St. James Infirmary                                          1944.0
#  1080.0  The Broken Record                                            1936.0
#  1489.0  Teressita                                                    1952.0
#  124.0   Dupree Blues                                                 1937.0
#  1682.0  Golden Wedding (Wedding In Gold)                             1945.0
#  905.0   Jumpin' Blues                                                1939.0
#  374.0   Love Me                                                      1939.0
#  1401.0  Love Of My Life                                              1940.0
#  1563.0  Peach Tree Street                                            1940.0
#  646.0   Pick A Rib                                                   1940.0
#  1640.0  Put That Ring On My Finger                                   1945.0
#  872.0   Rose O'day                                                   1942.0
#  302.0   Fur Trappers' Ball                                           1939.0
#  1791.0  1-2-3-4 Jump                                                 1946.0
#  1770.0  Yonder Goes My Baby                                          1945.0
#  157.0   Blowin' To California                                        1947.0
#  30.0    Drinkin' Wine Spo-Dee-O-Dee                                  1950.0
#  9.0     Sittin' On It All The Time                                   1949.0
#  118.0   Triflin' Woman                                               1950.0
#  577.0   Good Morning Corrine                                         1945.0
#  1673.0  Man, Have I Got Troubles                                     1950.0
#  60.0    Whiskey And Jelly Roll Blues                                 1946.0
#  527.0   Chopsticks Polka                                             1944.0
#  1300.0  Blue Again                                                   1930.0
#  1497.0  Washboard Blues                                              1945.0
#  698.0   Sram                                                        NaN
#  231.0   Oh! Lizzie (A Lover's Lament)                                1927.0
#  468.0   Zootcase                                                     1952.0
# NaN      NaN                                                         NaN
#
#         MP3 Avaliable                                                Link  \
# ID
#  296.0   Online        http://www.jazz-on-line.com/a/mp3e/V-D204A.mp3
#  1795.0  Online        http://www.jazz-on-line.com/a/mp3x/1927_076.mp3
#  416.0   Online        http://www.jazz-on-line.com/a/2c17/BB505899.mp3
#  1536.0  Online        http://www.jazz-on-line.com/a/2c17/BB505894.mp3
#  1647.0  Online        http://www.jazz-on-line.com/a/2016/BB502422.mp3
#  116.0   Online        http://www.jazz-on-line.com/a/2017/BB507370.mp3
#  574.0   Online        http://www.jazz-on-line.com/a/2016/BB502215.mp3
#  972.0   Online        http://www.jazz-on-line.com/a/mp3t/TS480444.mp3
#  1362.0  Online        http://www.jazz-on-line.com/a/mp3t/TS480695.mp3
#  868.0   Online        http://www.jazz-on-line.com/a/_inc/TS490814.mp3
#  1811.0  Online        http://www.jazz-on-line.com/a/_inc/TS490551.mp3
#  542.0   Online        http://www.jazz-on-line.com/a/_78_/SWIOSW207.mp3
#  125.0   Online        http://www.jazz-on-line.com/a/mp3a/VIC89327.mp3
#  384.0   Online        http://www.jazz-on-line.com/a/mp3e/CAP559-2A.mp3
#  1496.0  Online        http://www.jazz-on-line.com/a/mp4c/DEC70111.mp3
#  65.0    Online        http://www.jazz-on-line.com/a/mp3c/DEC70114.mp3
#  1391.0  Online        http://www.jazz-on-line.com/a/mp3d/LS488834.mp3
#  454.0   Online        http://www.jazz-on-line.com/a/mp3e/ALL155.mp3
#         Style-Katie                  Notes  \
# ID
#  296.0   None        Musical
#  1795.0  None        quality, musical
#  416.0   None        other
#  1536.0  None        musical, too complex
#  1647.0  None        singing
#  116.0   Lindy Hop   NaN
#  574.0   Lindy Hop   NaN
#  972.0   None        too complex
#  1362.0  None        too complex
#  868.0   None        too complex
#  1811.0  None        too complex
#  542.0   Balboa      Sound Quality
#  125.0   None        NaN
#  384.0   Balboa      Superlike
#  1496.0  Lindy Hop   NaN
#  65.0    Lindy Hop   NaN
#  1391.0  None        musical
#  454.0   None        singing
#  192.0   None        Latin
#  1193.0  None        too slow
#  385.0   None        musical
#  1723.0  Blues       not great
#  681.0   None        other
#  285.0   None        singing
#  95.0    Shag        vocals
#  451.0   None        sound quality
#  855.0   None        other
#  1183.0  None        quality, too complex
#  1700.0  None        musical
#  725.0   None        NaN
# ...       ...            ...
#  389.0   Lindy Hop   NaN
#  786.0   Blues       traditional
#  1080.0  Charleston  NaN
#  1489.0  None        musical
#  124.0   Lindy Hop   NaN
#  1682.0  None        musical
#  905.0   Lindy Hop   NaN
#  374.0   Lindy Hop   NaN
#  1401.0  Blues       slow swing
#  1563.0  Lindy Hop   singing
#  646.0   Lindy Hop   NaN
#  1640.0  Lindy Hop   NaN
#  872.0   None        musical
#  302.0   Balboa      NaN
#  1791.0  None        too complex
#  1770.0  Blues       traditional
#  157.0   Balboa      NaN
#  30.0    Lindy Hop   NaN
#  9.0     Lindy Hop   NaN
#  118.0   Blues       Traditional
#  577.0   Balboa      NaN
#  1673.0  Blues       traditional
#  60.0    Blues       Drag Blues, superlike
#  527.0   None        Musical, too complex
#  1300.0  Charleston  NaN
#  1497.0  Blues       slow swing, quality
#  698.0   NaN         NaN
#  231.0   None        Scratchy
#  468.0   None        modern jazz
# NaN      NaN         NaN
#
#                                                             Superlike
# ID
#  296.0   NaN
#  1795.0  NaN
#  416.0   NaN
#  1536.0  NaN
#  1647.0  NaN
#  116.0   NaN
#  574.0   NaN
#  972.0   NaN
#  1362.0  NaN
#  868.0   NaN
#  1811.0  NaN
#  542.0   NaN
#  125.0   NaN
#  384.0   Yes! - One of my favorites
#  1496.0  Yes! - I haven't heard this before, adding to my playlist...
#  65.0    NaN
#  1391.0  NaN
#  454.0   NaN
#  192.0   NaN
#  1193.0  NaN
#  385.0   NaN
#  1723.0  NaN
#  681.0   NaN
#  285.0   NaN
#  95.0    NaN
#  451.0   NaN
#  855.0   NaN
#  1183.0  NaN
#  1700.0  NaN
#  725.0   NaN
# ...      ...
#  389.0   NaN
#  786.0   NaN
#  1080.0  NaN
#  1489.0  NaN
#  124.0   NaN
#  1682.0  NaN
#  905.0   Yes! - One of my favorites
#  374.0   NaN
#  1401.0  NaN
#  1563.0  NaN
#  646.0   NaN
#  1640.0  NaN
#  872.0   NaN
#  302.0   NaN
#  1791.0  NaN
#  1770.0  NaN
#  157.0   NaN
#  30.0    NaN
#  9.0     NaN
#  118.0   NaN
#  577.0   NaN
#  1673.0  NaN
#  60.0    Yes! - One of my favorites
#  527.0   NaN
#  1300.0  NaN
#  1497.0  NaN
#  698.0   NaN
#  231.0   NaN
#  468.0   NaN
# NaN      NaN
#
# [1821 rows x 8 columns]
